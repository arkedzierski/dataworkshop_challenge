# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_absolute_error as mea

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = 'https://raw.githubusercontent.com/dataworkshop/5dwchallenge_2019/master/challenge5/input/airmiles.csv'
df = pd.read_csv(path)

df. head
# Out:
# <bound method NDFrame.head of     time  airmiles
# 0   1937       412
# 1   1938       480
# 2   1939       683
# 3   1940      1052
# 4   1941      1385
# 5   1942      1418
# 6   1943      1634
# 7   1944      2178
# 8   1945      3362
# 9   1946      5948
# 10  1947      6109
# 11  1948      5981
# 12  1949      6753
# 13  1950      8003
# 14  1951     10566
# 15  1952     12528
# 16  1953     14760
# 17  1954     16769
# 18  1955     19819
# 19  1956     22362
# 20  1957     25340
# 21  1958     25343
# 22  1959     29269
# 23  1960     30514>

# %%
plt.figure(figsize=(15,5))
plt.plot(df.time, df.airmiles, "o-");

# %%
df = pd.read_csv(path, parse_dates=['time'], index_col='time')
df[['airmiles']].plot();

# %%
df
# Out:
#             airmiles
# time
# 1937-01-01       412
# 1938-01-01       480
# 1939-01-01       683
# 1940-01-01      1052
# 1941-01-01      1385
# 1942-01-01      1418
# 1943-01-01      1634
# 1944-01-01      2178
# 1945-01-01      3362
# 1946-01-01      5948
# 1947-01-01      6109
# 1948-01-01      5981
# 1949-01-01      6753
# 1950-01-01      8003
# 1951-01-01     10566
# 1952-01-01     12528
# 1953-01-01     14760
# 1954-01-01     16769
# 1955-01-01     19819
# 1956-01-01     22362
# 1957-01-01     25340
# 1958-01-01     25343
# 1959-01-01     29269
# 1960-01-01     30514

# %%
def linear_func(airmiles, k=None, b=0):
    mean_value = np.mean(airmiles)
    if k is None:
        return [mean_value] * len(airmiles)
    return [idx*k+b for idx, _ in enumerate(airmiles)]

plt.figure(figsize=(15,5))
plt.plot(df.index, df.airmiles, "o-", label='orginal');
plt.plot(df.index, linear_func(df.airmiles), "x-", label='mean');
plt.plot(df.index, linear_func(df.airmiles, k=1300, b=-1000), "o-", label='mean1');

plt.legend()

# %% [markdown]
# Metryka sukcesu

# %%
print('mean', mea(df.airmiles, linear_func(df.airmiles)))
print('linear', mea(df.airmiles, linear_func(df.airmiles, k=1300, b=-2800)))
# Out:
# mean 8499.305555555557
# linear 2989.0833333333335
